# %%
import os
import uuid
import time
import threading
import cv2
import tkinter as tk
from PIL import Image, ImageTk
from tkinter import messagebox

# %%
IMAGES_PATH='Tensorflow/workspace/images/capturedImages'

# %%
labels = ['Facepalm','RaisedHand','Shh','GoodBye','Please']
no_img=5

# %%
class RoundedToggle(tk.Frame):
    def __init__(self, master=None, on_toggle=None, **kwargs):
        super().__init__(master, **kwargs)
        self.is_on = False
        self.on_toggle = on_toggle

        self.canvas = tk.Canvas(self, width=60, height=30, bg=self["bg"], highlightthickness=0)
        self.canvas.pack()

        self.bg = self.canvas.create_oval(0, 0, 30, 30, fill="#e5e7eb", outline="")
        self.bg2 = self.canvas.create_oval(30, 0, 60, 30, fill="#e5e7eb", outline="")
        self.bg_rect = self.canvas.create_rectangle(15, 0, 45, 30, fill="#e5e7eb", outline="")

        self.knob = self.canvas.create_oval(3, 3, 27, 27, fill="white", outline="")

        self.canvas.bind("<Button-1>", self.toggle)

    def toggle(self, event=None):
        self.is_on = not self.is_on
        if self.is_on:
            self.canvas.itemconfig(self.bg, fill="#4ade80")
            self.canvas.itemconfig(self.bg2, fill="#4ade80")
            self.canvas.itemconfig(self.bg_rect, fill="#4ade80")
            self.canvas.coords(self.knob, 33, 3, 57, 27)
        else:
            self.canvas.itemconfig(self.bg, fill="#e5e7eb")
            self.canvas.itemconfig(self.bg2, fill="#e5e7eb")
            self.canvas.itemconfig(self.bg_rect, fill="#e5e7eb")
            self.canvas.coords(self.knob, 3, 3, 27, 27)

        if self.on_toggle:
            self.on_toggle(self.is_on)


def toggle_voice_feedback(state):
    if state:
        voice_toggle_label.config(text="Voice Feedback Enabled")
    else:
        voice_toggle_label.config(text="Voice Feedback Disabled")


def update_camera():
    ret, frame = cap.read()
    if ret:
        frame = cv2.flip(frame, 1)
        img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(img)
        imgtk = ImageTk.PhotoImage(image=img)
        camera_label.imgtk = imgtk
        camera_label.configure(image=imgtk)
    camera_label.after(10, update_camera)


def capture_images(label):
    os.makedirs(f'{IMAGES_PATH}{label}', exist_ok=True)
    print(f"\nGet ready to capture images for: {label}")
    time.sleep(1)

    for _ in range(10):  
        cap.read()
        time.sleep(0.05)

    print("Starting 5-second capture...")
    start_time = time.time()
    while time.time() - start_time <= 5:
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame.")
            break

        frame = cv2.flip(frame, 1)
        imagename = os.path.join(IMAGES_PATH, label, f'{label}.{str(uuid.uuid1())}.jpg')
        cv2.imwrite(imagename, frame)
        print(f"Saved {imagename}")
        time.sleep(0.3)

    messagebox.showinfo("Done Caputring")

def start_capture_thread():
    def on_select():
        selected_label = label_var.get()
        if selected_label in labels:
            popup.destroy()
            threading.Thread(target=capture_images, args=(selected_label,), daemon=True).start()

    popup = tk.Toplevel(root)
    popup.title("Select Label")
    popup.geometry("300x120")
    popup.configure(bg="#f6f9fc")

    label_prompt = tk.Label(popup, text="Select label for capture:", bg="#f6f9fc", font=("Segoe UI", 10))
    label_prompt.pack(pady=(15, 5))

    label_var = tk.StringVar(popup)
    label_var.set(labels[0])  

    dropdown = tk.OptionMenu(popup, label_var, *labels)
    dropdown.pack(pady=5)

    confirm_btn = tk.Button(popup, text="Start Capture", command=on_select, bg="#60a5fa", fg="white",
                            font=("Segoe UI", 10, "bold"))
    confirm_btn.pack(pady=(5, 10))



root = tk.Tk()
root.title("Hand Gesture Recognizer")
root.geometry("1000x700")
root.configure(bg="#f6f9fc")

title = tk.Label(root, text="Hand Gesture Recognizer", font=("Segoe UI", 24, "bold"), bg="#f6f9fc")
title.pack(pady=(20, 0))

subtitle = tk.Label(root, text="Display hand gestures as text and hear them spoken aloud", font=("Segoe UI", 12),
                    fg="#6b7280", bg="#f6f9fc")
subtitle.pack(pady=(5, 20))

main_frame = tk.Frame(root, bg="#f6f9fc")
main_frame.pack(fill="both", expand=True, padx=20, pady=10)

camera_frame = tk.Frame(main_frame, bg="#f6f9fc")
camera_frame.pack(side="left", fill="both", expand=True, padx=(0, 10))

camera_box = tk.Frame(camera_frame, bg="#fee2e2", width=640, height=400,
                      highlightbackground="#60a5fa", highlightcolor="#60a5fa", highlightthickness=2)
camera_box.pack(fill="both", expand=True)
camera_box.pack_propagate(False)

camera_label = tk.Label(camera_box, text="Camera initializing...", bg="#fee2e2", fg="#b91c1c",
                        font=("Segoe UI", 12))
camera_label.pack(expand=True)

detection_label = tk.Label(camera_frame, text="● Detection Active", fg="#22c55e", bg="#f6f9fc",
                           font=("Segoe UI", 10, "bold"))
detection_label.pack(pady=5)

gesture_frame = tk.Frame(main_frame, width=300, height=400, bg="white", bd=1, relief="solid")
gesture_frame.pack(side="left", fill="y", padx=(10, 0))
gesture_frame.pack_propagate(False)

gesture_title = tk.Label(gesture_frame, text="Recognized Gesture", font=("Segoe UI", 16, "bold"), bg="white")
gesture_title.pack(pady=(20, 10))

gesture_icon = tk.Label(gesture_frame, text="📷", font=("Segoe UI", 32), bg="white", fg="#cbd5e1")
gesture_icon.pack(pady=10)

gesture_text = tk.Label(gesture_frame, text="No gesture detected", font=("Segoe UI", 12), fg="#6b7280", bg="white")
gesture_text.pack()

gesture_subtext = tk.Label(gesture_frame, text="Show your hand to the camera", font=("Segoe UI", 10),
                           fg="#9ca3af", bg="white")
gesture_subtext.pack(pady=(5, 0))

bottom_frame = tk.Frame(root, bg="#f6f9fc")
bottom_frame.pack(side="bottom", fill="x", pady=10, padx=20)

voice_toggle = RoundedToggle(bottom_frame, on_toggle=toggle_voice_feedback, bg="#f6f9fc")
voice_toggle.pack(side="left", padx=(0, 5))

voice_toggle_label = tk.Label(bottom_frame, text="Voice Feedback Disabled", font=("Segoe UI", 10),
                              fg="#374151", bg="#f6f9fc")
voice_toggle_label.pack(side="left")

capture_button = tk.Button(bottom_frame, text="Start Capture", font=("Segoe UI", 10, "bold"), bg="#60a5fa",
                           fg="white", command=start_capture_thread)
capture_button.pack(side="right")

cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

update_camera()  
root.mainloop()

cap.release()
cv2.destroyAllWindows()
# Out:
# Get ready to capture images for: Facepalm
# Starting 5-second capture...
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8cdede43-2e7a-11f0-96e5-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8d0d27ae-2e7a-11f0-bda9-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8d3ccd8d-2e7a-11f0-b538-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8d6d2d26-2e7a-11f0-98af-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8d9c5e68-2e7a-11f0-8ceb-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8dcc0a32-2e7a-11f0-8af7-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8dfb7177-2e7a-11f0-a6f7-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8e2b319e-2e7a-11f0-a802-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8e5aa34a-2e7a-11f0-8bcf-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8e8a5173-2e7a-11f0-86e1-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8eba5c24-2e7a-11f0-9724-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8ee9c7bd-2e7a-11f0-917f-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8f199985-2e7a-11f0-9e4b-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8f4955db-2e7a-11f0-8b5a-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8f793d27-2e7a-11f0-a3a7-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.8fa919fc-2e7a-11f0-a617-010101010000.jpg
#
# Get ready to capture images for: Facepalm
# Starting 5-second capture...
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.bdd4b325-2e7a-11f0-8927-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.be121870-2e7a-11f0-a506-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.be4164f7-2e7a-11f0-b244-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.be70c6c3-2e7a-11f0-ab8f-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.be9fc6b6-2e7a-11f0-863a-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.becf24a4-2e7a-11f0-9686-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.beff0402-2e7a-11f0-b746-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.bf2e6f8b-2e7a-11f0-921f-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.bf5d925e-2e7a-11f0-97f5-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.bf8d55c7-2e7a-11f0-9cb3-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.bfbd33c2-2e7a-11f0-9e0a-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.bff0ad71-2e7a-11f0-9861-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.c01f90b5-2e7a-11f0-b8d1-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.c04e1e73-2e7a-11f0-9b5d-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.c07ddddc-2e7a-11f0-84b6-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Facepalm\Facepalm.c0ad7400-2e7a-11f0-a973-010101010000.jpg
#
# Get ready to capture images for: RaisedHand
# Starting 5-second capture...
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.cf665bb7-2e7a-11f0-8405-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.cf94a4e9-2e7a-11f0-941a-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.cfc43d95-2e7a-11f0-b4a7-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.cff3c866-2e7a-11f0-8f1d-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d02388e0-2e7a-11f0-91a7-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d0535b70-2e7a-11f0-869b-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d0838cef-2e7a-11f0-9536-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d0b9523f-2e7a-11f0-9738-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d0e9f8cf-2e7a-11f0-bd20-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d1193d13-2e7a-11f0-adc7-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d148d54d-2e7a-11f0-b7fe-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d1789753-2e7a-11f0-9bdf-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d1a80818-2e7a-11f0-9588-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d1d72d36-2e7a-11f0-9ca8-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d206e292-2e7a-11f0-9f61-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.d23860c1-2e7a-11f0-8ca0-010101010000.jpg
#
# Get ready to capture images for: Shh
# Starting 5-second capture...
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.df380a54-2e7a-11f0-a59b-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.df66e2ef-2e7a-11f0-a02a-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.df973f0e-2e7a-11f0-9ce3-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.dfc70425-2e7a-11f0-ba0d-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.dff69af1-2e7a-11f0-83a6-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e0260ce1-2e7a-11f0-9c9d-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e0561197-2e7a-11f0-9bff-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e08bbce4-2e7a-11f0-9d6f-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e0ba0ed0-2e7a-11f0-8ede-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e0e99c41-2e7a-11f0-a647-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e117f897-2e7a-11f0-88cc-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e14854da-2e7a-11f0-bd30-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e1781d66-2e7a-11f0-b1b5-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e1ae2d80-2e7a-11f0-b5f1-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e1dda63e-2e7a-11f0-8ba6-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.e20d3e8b-2e7a-11f0-b285-010101010000.jpg
#
# Get ready to capture images for: RaisedHand
# Starting 5-second capture...
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.0766709e-2e7b-11f0-9d30-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.07955af2-2e7b-11f0-a655-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.07c4c58f-2e7b-11f0-9eef-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.07f49208-2e7b-11f0-afbf-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.08242a7e-2e7b-11f0-9f59-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.08539402-2e7b-11f0-b123-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.08833031-2e7b-11f0-a1a8-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.08b2b740-2e7b-11f0-970a-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.08e2bab7-2e7b-11f0-83ab-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.0916b72a-2e7b-11f0-b521-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.0946b3e6-2e7b-11f0-b732-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.0976bede-2e7b-11f0-96c8-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.09a643ab-2e7b-11f0-953e-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.09d5e388-2e7b-11f0-ae78-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.0a0d875f-2e7b-11f0-84ee-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\RaisedHand\RaisedHand.0a3c93ed-2e7b-11f0-87cb-010101010000.jpg
#
# Get ready to capture images for: Shh
# Starting 5-second capture...
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.0eec959e-2e7b-11f0-8312-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.0f1c2065-2e7b-11f0-a322-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.0f4c1b14-2e7b-11f0-a5d9-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.0f7b48c7-2e7b-11f0-a99c-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.0faaf6ff-2e7b-11f0-820a-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.0fdaa718-2e7b-11f0-83ef-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.100a6406-2e7b-11f0-8c93-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.103dab57-2e7b-11f0-8a5b-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.106dffd5-2e7b-11f0-af54-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.109dce00-2e7b-11f0-b891-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.10cd18e5-2e7b-11f0-b099-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.10fc966c-2e7b-11f0-bc1f-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.112c6ce3-2e7b-11f0-b422-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.115c755b-2e7b-11f0-9bea-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.1190dc0f-2e7b-11f0-bec2-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Shh\Shh.11c07f5d-2e7b-11f0-9d32-010101010000.jpg
#
# Get ready to capture images for: GoodBye
# Starting 5-second capture...
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2c846123-2e7b-11f0-852d-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2cb333c8-2e7b-11f0-af77-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2ce2f45c-2e7b-11f0-9230-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2d129bcf-2e7b-11f0-a9b4-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2d422fc9-2e7b-11f0-9be3-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2d71abe0-2e7b-11f0-87fb-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2da0a447-2e7b-11f0-92ed-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2dd0acee-2e7b-11f0-8c90-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2e06377b-2e7b-11f0-9460-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2e36dab0-2e7b-11f0-9163-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2e666d07-2e7b-11f0-a6ae-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2e961e52-2e7b-11f0-877c-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2ec61f73-2e7b-11f0-8967-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2efa6d61-2e7b-11f0-bb3b-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2f29db15-2e7b-11f0-a86e-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\GoodBye\GoodBye.2f593db9-2e7b-11f0-a03a-010101010000.jpg
#
# Get ready to capture images for: Please
# Starting 5-second capture...
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.34e1f471-2e7b-11f0-806f-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.3512876c-2e7b-11f0-878e-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.35413262-2e7b-11f0-b82e-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.35828d20-2e7b-11f0-bb54-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.35b885f5-2e7b-11f0-bb6c-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.35e8c277-2e7b-11f0-a985-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.36187383-2e7b-11f0-900e-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.36485a00-2e7b-11f0-b130-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.3677667d-2e7b-11f0-af47-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.36a719be-2e7b-11f0-b957-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.36dd85d0-2e7b-11f0-9b7e-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.370db728-2e7b-11f0-95e1-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.3749c74f-2e7b-11f0-832a-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.377960b4-2e7b-11f0-9f3f-010101010000.jpg
# Saved Tensorflow/workspace/images/capturedImages\Please\Please.37a916fd-2e7b-11f0-9eb8-010101010000.jpg
